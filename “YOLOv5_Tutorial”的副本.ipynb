# %% [markdown]
# <a href="https://colab.research.google.com/github/wmh02240/3D-convolutional-speaker-recognition-pytorch/blob/master/%E2%80%9CYOLOv5_Tutorial%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/26833433/98702494-b71c4e80-237a-11eb-87ed-17fcd6b3f066.jpg">
#
# This notebook was written by Ultralytics LLC, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://www.ultralytics.com.

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases).

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/
Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='data/images/', update=False, view_img=False, weights=['yolov5s.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079MB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v3.1/yolov5s.pt to yolov5s.pt...
# 100% 14.5M/14.5M [00:00<00:00, 85.2MB/s]
#
# Fusing layers...
# Model Summary: 232 layers, 7459581 parameters, 0 gradients, 17.5 GFLOPS
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 buss, 1 skateboards, Done. (0.035s)
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, Done. (0.011s)
# Results saved to runs/detect/exp
# Done. (0.243s)

# %% [markdown]
# Results are saved to `runs/detect`. A full list of available inference sources:
# <img src="https://user-images.githubusercontent.com/26833433/98274798-2b7a7a80-1f94-11eb-91a4-70c73593e26b.jpg" width="900">

# %% [markdown]
# # 2. Test
# Test a model on [COCO](https://cocodataset.org/#home) val or test-dev dataset to evaluate trained accuracy. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be 1-2% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val2017
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=819257867.0), HTML(value='')))

# %%
# Run YOLOv5x on COCO val2017
# !python test.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='./data/coco.yaml', device='', exist_ok=False, img_size=640, iou_thres=0.65, name='exp', project='runs/test', save_conf=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['yolov5x.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16130MB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v3.1/yolov5x.pt to yolov5x.pt...
# 100% 170M/170M [00:05<00:00, 32.6MB/s]
#
# Fusing layers...
# Model Summary: 484 layers, 88922205 parameters, 0 gradients
# Scanning labels ../coco/labels/val2017.cache (4952 found, 0 missing, 48 empty, 0 duplicate, for 5000 images): 5000it [00:00, 14785.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100% 157/157 [01:30<00:00,  1.74it/s]
#                  all       5e+03    3.63e+04       0.409       0.754       0.672       0.484
# Speed: 5.9/2.1/7.9 ms inference/NMS/total per 640x640 image at batch-size 32
#
# Evaluating pycocotools mAP... saving runs/test/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.43s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=4.67s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=92.11s).
# Accumulating evaluation results...
# DONE (t=13.24s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.492
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.676
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.534
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.318
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.541
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.633
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.376
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.617
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.670
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.493
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.812
# Results saved to runs/test/exp

# %% [markdown]
# ## COCO test-dev2017
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (20,000 images). Results are saved to a `*.json` file which can be submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip  # unzip labels
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f && rm $f  # 7GB,  41k images
# %mv ./test2017 ./coco/images && mv ./coco ../  # move images to /coco and move /coco next to /yolov5

# %%
# Run YOLOv5s on COCO test-dev2017 using --task test
# !python test.py --weights yolov5s.pt --data coco.yaml --task test

# %% [markdown]
# # 3. Train
#
# Download [COCO128](https://www.kaggle.com/ultralytics/coco128), a small 128-image tutorial dataset, start tensorboard and train YOLOv5s from a pretrained checkpoint for 3 epochs (note actual training is typically much longer, around **300-1000 epochs**, depending on your dataset).

# %%
# Download COCO128
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22091032.0), HTML(value='')))

# %% [markdown]
# Train a YOLOv5s model on [COCO128](https://www.kaggle.com/ultralytics/coco128) with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and **COCO, COCO128, and VOC datasets are downloaded automatically** on first use.
#
# All training results are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.

# %%
# Tensorboard (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases (optional)
# %pip install -q wandb  
# !wandb login  # use 'wandb disabled' or 'wandb enabled' to disable or enable
# Out:
#      |████████████████████████████████| 1.8MB 23.1MB/s
#      |████████████████████████████████| 133kB 61.1MB/s
#      |████████████████████████████████| 102kB 13.8MB/s
#      |████████████████████████████████| 81kB 13.0MB/s
#      |████████████████████████████████| 163kB 51.5MB/s
#      |████████████████████████████████| 71kB 11.8MB/s
#   Building wheel for subprocess32 (setup.py) ... done
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 300 --data coco128.yaml --weights yolov5s.pt --nosave --cache
# Out:
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=True, cfg='', data='./data/coco128.yaml', device='', epochs=300, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='exp', noautoanchor=False, nosave=True, notest=False, project='runs/train', rect=False, resume=False, save_dir='runs/train/exp2', single_cls=False, sync_bn=False, total_batch_size=16, weights='yolov5s.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2020-12-24 01:42:20.368064: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Hyperparameters {'lr0': 0.01, 'lrf': 0.2, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'box': 0.05, 'cls': 0.5, 'cls_pw': 1.0, 'obj': 1.0, 'obj_pw': 1.0, 'iou_t': 0.2, 'anchor_t': 4.0, 'fl_gamma': 0.0, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'mosaic': 1.0, 'mixup': 0.0}
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7468157 parameters, 7468157 gradients, 17.5 GFLOPS
#
# Transferred 370/370 items from yolov5s.pt
# Optimizer groups: 62 .bias, 70 conv.weight, 59 other
# wandb: Currently logged in as: wmh02240 (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.10.12
# wandb: Syncing run exp2
# wandb: ⭐️ View project at https://wandb.ai/wmh02240/YOLOv5
# wandb: 🚀 View run at https://wandb.ai/wmh02240/YOLOv5/runs/29or7gxf
# wandb: Run data is saved locally in /content/yolov5/wandb/run-20201224_014226-29or7gxf
# wandb: Run `wandb offline` to turn off syncing.
#
# Scanning '../coco128/labels/train2017.cache' for images and labels... 128 found, 0 missing, 2 empty, 0 corrupted: 100%|██████████| 128/128 [00:00<00:00, 412026.79it/s]
# Caching images (0.1GB): 100%|██████████| 128/128 [00:00<00:00, 207.51it/s]
# Scanning '../coco128/labels/train2017.cache' for images and labels... 128 found, 0 missing, 2 empty, 0 corrupted: 100%|██████████| 128/128 [00:00<00:00, 110308.39it/s]
# Caching images (0.1GB): 100%|██████████| 128/128 [00:00<00:00, 166.08it/s]
# Plotting labels...
# NumExpr defaulting to 2 threads.
# Images sizes do not match. This will causes images to be display incorrectly in the UI.
#
# Analyzing anchors... anchors/target = 4.26, Best Possible Recall (BPR) = 0.9946
# Image sizes 640 train, 640 test
# Using 2 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 300 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      0/299     5.28G   0.04202   0.06746   0.01503    0.1245       194       640: 100%|██████████| 8/8 [00:05<00:00,  1.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:07<00:00,  1.11it/s]
#                  all         128         929       0.406       0.762       0.701       0.458
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      1/299     4.51G   0.04461   0.05872   0.01689    0.1202       142       640: 100%|██████████| 8/8 [00:02<00:00,  3.45it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.38it/s]
#                  all         128         929       0.389       0.764         0.7       0.462
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      2/299     4.51G   0.04442   0.06537   0.01661    0.1264       149       640: 100%|██████████| 8/8 [00:02<00:00,  3.51it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.92it/s]
#                  all         128         929       0.382       0.766       0.701       0.461
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      3/299     4.51G   0.04243   0.06085   0.01549    0.1188       124       640: 100%|██████████| 8/8 [00:02<00:00,  3.42it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.45it/s]
#                  all         128         929       0.388       0.772       0.706       0.467
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      4/299     4.51G   0.04317   0.06171    0.0163    0.1212       158       640: 100%|██████████| 8/8 [00:02<00:00,  3.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.51it/s]
#                  all         128         929       0.386       0.775       0.713       0.475
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      5/299     4.51G   0.04082   0.05516   0.01562    0.1116       180       640: 100%|██████████| 8/8 [00:02<00:00,  3.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.84it/s]
#                  all         128         929       0.386        0.78       0.715       0.478
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      6/299     4.51G   0.04281   0.06605   0.01554    0.1244       198       640: 100%|██████████| 8/8 [00:02<00:00,  3.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.02it/s]
#                  all         128         929       0.388       0.788       0.722       0.479
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      7/299     4.51G   0.04451    0.0632   0.01582    0.1235       207       640: 100%|██████████| 8/8 [00:02<00:00,  3.46it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.98it/s]
#                  all         128         929        0.39        0.79       0.737       0.483
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      8/299     4.51G   0.04151   0.06035   0.01586    0.1177       240       640: 100%|██████████| 8/8 [00:02<00:00,  3.45it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.89it/s]
#                  all         128         929       0.399       0.792       0.735        0.49
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#      9/299     4.51G   0.04094   0.05241   0.01516    0.1085       217       640: 100%|██████████| 8/8 [00:02<00:00,  3.32it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.72it/s]
#                  all         128         929       0.407       0.804       0.754       0.499
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     10/299     4.51G   0.04087   0.06141   0.01478    0.1171       183       640: 100%|██████████| 8/8 [00:02<00:00,  3.44it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.58it/s]
#                  all         128         929       0.409       0.806        0.76       0.511
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     11/299     4.51G    0.0407    0.0577   0.01351    0.1119       196       640: 100%|██████████| 8/8 [00:02<00:00,  3.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.73it/s]
#                  all         128         929       0.407       0.805       0.763       0.513
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     12/299     4.51G   0.04009   0.06096   0.01385    0.1149       160       640: 100%|██████████| 8/8 [00:02<00:00,  3.47it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.90it/s]
#                  all         128         929       0.404       0.802        0.77       0.523
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     13/299     4.51G   0.04219   0.06279   0.01252    0.1175       219       640: 100%|██████████| 8/8 [00:02<00:00,  3.50it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.45it/s]
#                  all         128         929       0.405       0.801       0.767       0.526
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     14/299     4.51G   0.04011   0.05593   0.01314    0.1092       169       640: 100%|██████████| 8/8 [00:02<00:00,  3.38it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.42it/s]
#                  all         128         929       0.413       0.818       0.776       0.531
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     15/299     4.51G   0.03887   0.05537    0.0131    0.1074       151       640: 100%|██████████| 8/8 [00:02<00:00,  3.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.44it/s]
#                  all         128         929       0.418       0.821       0.778       0.536
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     16/299     4.51G   0.04079    0.0614   0.01276     0.115       143       640: 100%|██████████| 8/8 [00:02<00:00,  3.48it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.78it/s]
#                  all         128         929       0.425       0.821       0.781       0.538
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     17/299     4.51G   0.03936   0.06053   0.01312     0.113       171       640: 100%|██████████| 8/8 [00:02<00:00,  3.29it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.05it/s]
#                  all         128         929       0.426       0.826       0.788       0.545
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     18/299     4.51G     0.042   0.05756   0.01272    0.1123       195       640: 100%|██████████| 8/8 [00:02<00:00,  3.36it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.52it/s]
#                  all         128         929       0.435       0.831       0.791       0.546
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     19/299     4.51G   0.03849   0.05201   0.01124    0.1017       185       640: 100%|██████████| 8/8 [00:02<00:00,  3.37it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.06it/s]
#                  all         128         929       0.452       0.833         0.8       0.557
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     20/299     4.51G    0.0401   0.05783   0.01051    0.1084       206       640: 100%|██████████| 8/8 [00:02<00:00,  3.41it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.79it/s]
#                  all         128         929       0.454       0.837       0.801       0.555
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     21/299     4.51G   0.03926   0.05422   0.01006    0.1035       193       640: 100%|██████████| 8/8 [00:02<00:00,  3.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.96it/s]
#                  all         128         929       0.452       0.842       0.808       0.564
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     22/299     4.51G   0.03856   0.05334  0.009826    0.1017       204       640: 100%|██████████| 8/8 [00:02<00:00,  3.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.05it/s]
#                  all         128         929       0.454       0.845       0.819       0.573
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     23/299     4.51G   0.03924   0.05734   0.01103    0.1076       228       640: 100%|██████████| 8/8 [00:02<00:00,  3.73it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.80it/s]
#                  all         128         929        0.46       0.851       0.821       0.576
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     24/299     4.51G   0.03965   0.05446   0.01025    0.1044       231       640: 100%|██████████| 8/8 [00:02<00:00,  3.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.94it/s]
#                  all         128         929       0.472       0.854       0.824       0.574
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     25/299     4.51G   0.03934   0.05247   0.01141    0.1032       109       640: 100%|██████████| 8/8 [00:02<00:00,  3.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.50it/s]
#                  all         128         929       0.483       0.861       0.832       0.573
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     26/299     4.51G    0.0387   0.05631   0.01074    0.1058       274       640: 100%|██████████| 8/8 [00:02<00:00,  3.51it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.85it/s]
#                  all         128         929       0.485       0.866       0.839        0.57
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     27/299     4.51G   0.03847   0.05475   0.01001    0.1032       244       640: 100%|██████████| 8/8 [00:02<00:00,  3.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.00it/s]
#                  all         128         929       0.479       0.874       0.841       0.586
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     28/299     4.51G   0.03927   0.05517   0.01056     0.105       186       640: 100%|██████████| 8/8 [00:02<00:00,  3.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.98it/s]
#                  all         128         929       0.485       0.882       0.853       0.589
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     29/299     4.51G   0.03895   0.05116   0.01065    0.1008       159       640: 100%|██████████| 8/8 [00:02<00:00,  3.54it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.07it/s]
#                  all         128         929       0.503       0.878       0.852       0.599
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     30/299     4.51G   0.03927   0.05366  0.009123     0.102       259       640: 100%|██████████| 8/8 [00:02<00:00,  3.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.56it/s]
#                  all         128         929       0.506       0.893       0.861       0.598
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     31/299     4.51G   0.03765   0.05329   0.01046    0.1014       229       640: 100%|██████████| 8/8 [00:02<00:00,  3.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.54it/s]
#                  all         128         929       0.511       0.899       0.865       0.601
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     32/299     4.51G   0.03975   0.05379  0.009845    0.1034       172       640: 100%|██████████| 8/8 [00:02<00:00,  3.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.57it/s]
#                  all         128         929        0.51       0.896       0.862       0.602
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     33/299     4.51G   0.03836    0.0547  0.008149    0.1012       230       640: 100%|██████████| 8/8 [00:02<00:00,  3.66it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.04it/s]
#                  all         128         929       0.494         0.9       0.863       0.603
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     34/299     4.51G    0.0393   0.04943  0.008914   0.09764       202       640: 100%|██████████| 8/8 [00:02<00:00,  3.54it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.58it/s]
#                  all         128         929       0.499       0.891       0.863       0.593
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     35/299     4.51G    0.0389   0.04923  0.009209   0.09734       184       640: 100%|██████████| 8/8 [00:02<00:00,  3.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.92it/s]
#                  all         128         929       0.505       0.895       0.866       0.596
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     36/299     4.51G   0.03935   0.05207  0.009257    0.1007       228       640: 100%|██████████| 8/8 [00:02<00:00,  3.61it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.96it/s]
#                  all         128         929       0.511       0.904       0.872       0.595
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     37/299     4.51G   0.03953   0.05374  0.008865    0.1021       193       640: 100%|██████████| 8/8 [00:02<00:00,  3.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.04it/s]
#                  all         128         929       0.497       0.903       0.879       0.607
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     38/299     4.51G   0.03971   0.05189  0.008344   0.09994       188       640: 100%|██████████| 8/8 [00:02<00:00,  3.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.02it/s]
#                  all         128         929       0.516       0.899       0.876       0.608
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     39/299     4.51G   0.04018    0.0516  0.008423    0.1002       228       640: 100%|██████████| 8/8 [00:02<00:00,  3.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.31it/s]
#                  all         128         929       0.524       0.904       0.877       0.604
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     40/299     4.51G   0.04002   0.04849  0.008706   0.09722       157       640: 100%|██████████| 8/8 [00:02<00:00,  3.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.96it/s]
#                  all         128         929       0.535       0.911       0.879       0.587
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     41/299     4.51G   0.03836   0.04773  0.008223   0.09431       236       640: 100%|██████████| 8/8 [00:02<00:00,  3.55it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.02it/s]
#                  all         128         929       0.531       0.908       0.878       0.584
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     42/299     4.51G   0.03912   0.04899  0.008306   0.09641       214       640: 100%|██████████| 8/8 [00:02<00:00,  3.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.05it/s]
#                  all         128         929       0.502       0.898       0.857       0.585
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     43/299     4.51G   0.03843   0.04814   0.00932   0.09589       163       640: 100%|██████████| 8/8 [00:02<00:00,  3.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.89it/s]
#                  all         128         929       0.518       0.909       0.879       0.603
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     44/299     4.51G   0.03747   0.04461  0.008516   0.09059       190       640: 100%|██████████| 8/8 [00:02<00:00,  3.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.10it/s]
#                  all         128         929       0.533       0.911        0.89       0.608
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     45/299     4.51G   0.03741   0.04892  0.007595   0.09393       183       640: 100%|██████████| 8/8 [00:02<00:00,  3.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.02it/s]
#                  all         128         929       0.523       0.916       0.887       0.607
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     46/299     4.51G   0.03853   0.04605  0.009104   0.09369       168       640: 100%|██████████| 8/8 [00:02<00:00,  3.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]
#                  all         128         929       0.519       0.926       0.888       0.599
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     47/299     4.51G   0.04027    0.0476  0.008138     0.096       211       640: 100%|██████████| 8/8 [00:02<00:00,  3.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.05it/s]
#                  all         128         929        0.53       0.922       0.897       0.635
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     48/299     4.51G    0.0381   0.04394  0.007156    0.0892       195       640: 100%|██████████| 8/8 [00:02<00:00,  3.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.92it/s]
#                  all         128         929       0.536       0.911       0.897       0.612
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     49/299     4.51G   0.03764   0.04562  0.008211   0.09147       153       640: 100%|██████████| 8/8 [00:02<00:00,  3.57it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.43it/s]
#                  all         128         929       0.534       0.911       0.897       0.615
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     50/299     4.51G   0.03829   0.04705  0.007221   0.09256       194       640: 100%|██████████| 8/8 [00:02<00:00,  3.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.53it/s]
#                  all         128         929       0.536        0.91       0.896       0.625
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     51/299     4.51G   0.03835    0.0472  0.007916   0.09347       188       640: 100%|██████████| 8/8 [00:02<00:00,  3.53it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.77it/s]
#                  all         128         929       0.545       0.926       0.896       0.619
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     52/299     4.51G   0.03791   0.05061  0.007168   0.09569       164       640: 100%|██████████| 8/8 [00:02<00:00,  3.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.16it/s]
#                  all         128         929       0.535       0.933       0.904       0.643
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     53/299     4.51G   0.03885   0.04747  0.007753   0.09407       147       640: 100%|██████████| 8/8 [00:02<00:00,  3.59it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.52it/s]
#                  all         128         929       0.528       0.934       0.905       0.581
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     54/299     4.51G   0.03794   0.04798  0.007189   0.09311       175       640: 100%|██████████| 8/8 [00:02<00:00,  3.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.05it/s]
#                  all         128         929       0.557       0.928       0.906       0.638
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     55/299     4.51G   0.03736   0.04461  0.007716   0.08968       153       640: 100%|██████████| 8/8 [00:02<00:00,  3.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]
#                  all         128         929       0.546       0.934       0.906       0.658
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     56/299     4.51G   0.03626   0.04559  0.008161      0.09       198       640: 100%|██████████| 8/8 [00:02<00:00,  3.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.43it/s]
#                  all         128         929       0.544       0.937       0.916       0.644
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     57/299     4.51G   0.03735    0.0459  0.007384   0.09064       160       640: 100%|██████████| 8/8 [00:02<00:00,  3.55it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.04it/s]
#                  all         128         929       0.551       0.944        0.92       0.657
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     58/299     4.51G   0.03617   0.04845  0.006516   0.09113       221       640: 100%|██████████| 8/8 [00:02<00:00,  3.61it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.71it/s]
#                  all         128         929       0.524        0.94       0.892        0.61
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     59/299     4.51G   0.03944   0.04789  0.006919   0.09425       202       640: 100%|██████████| 8/8 [00:02<00:00,  3.49it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.54it/s]
#                  all         128         929       0.568       0.943        0.91       0.658
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     60/299     4.51G   0.03729   0.04767   0.00746   0.09243       243       640: 100%|██████████| 8/8 [00:02<00:00,  3.49it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.79it/s]
#                  all         128         929        0.58       0.937       0.913       0.651
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     61/299     4.51G   0.03585   0.04217  0.006081    0.0841       300       640: 100%|██████████| 8/8 [00:02<00:00,  3.50it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.00it/s]
#                  all         128         929       0.563       0.943       0.914       0.655
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     62/299     4.51G   0.03755   0.04752  0.007292   0.09237       208       640: 100%|██████████| 8/8 [00:02<00:00,  3.48it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.42it/s]
#                  all         128         929       0.555       0.944        0.92       0.642
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     63/299     4.51G   0.03826   0.04567  0.006796   0.09073       155       640: 100%|██████████| 8/8 [00:02<00:00,  3.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.61it/s]
#                  all         128         929       0.478       0.943       0.879       0.566
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     64/299     4.51G   0.04127   0.04521  0.007087   0.09357       189       640: 100%|██████████| 8/8 [00:02<00:00,  3.54it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.05it/s]
#                  all         128         929       0.511       0.938       0.892       0.571
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     65/299     4.51G   0.04396   0.04798   0.00672   0.09866       182       640: 100%|██████████| 8/8 [00:02<00:00,  3.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.99it/s]
#                  all         128         929       0.539       0.934       0.895       0.612
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     66/299     4.51G    0.0391   0.04312  0.006244   0.08847       172       640: 100%|██████████| 8/8 [00:02<00:00,  3.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.66it/s]
#                  all         128         929       0.544       0.941       0.917       0.621
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     67/299     4.51G   0.03839   0.04971  0.006845   0.09495       212       640: 100%|██████████| 8/8 [00:02<00:00,  3.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.89it/s]
#                  all         128         929       0.544       0.942       0.911       0.632
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     68/299     4.51G   0.04179    0.0486  0.007504    0.0979       208       640: 100%|██████████| 8/8 [00:02<00:00,  3.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.55it/s]
#                  all         128         929       0.567        0.94       0.913        0.63
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     69/299     4.51G   0.04233   0.04464  0.007972   0.09494       301       640: 100%|██████████| 8/8 [00:02<00:00,  3.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.49it/s]
#                  all         128         929        0.57       0.935       0.909       0.624
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     70/299     4.51G    0.0386   0.04397  0.006573   0.08914       203       640: 100%|██████████| 8/8 [00:02<00:00,  3.53it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.01it/s]
#                  all         128         929       0.571       0.943       0.911        0.65
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     71/299     4.51G   0.04072   0.04246  0.007616   0.09079       213       640: 100%|██████████| 8/8 [00:02<00:00,  3.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.07it/s]
#                  all         128         929       0.569       0.933       0.903        0.62
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     72/299     4.51G   0.04183   0.04838  0.006864   0.09708       200       640: 100%|██████████| 8/8 [00:02<00:00,  3.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.77it/s]
#                  all         128         929       0.561       0.935        0.91       0.634
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     73/299     4.51G   0.03861   0.04384  0.008029   0.09047       192       640: 100%|██████████| 8/8 [00:02<00:00,  3.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.00it/s]
#                  all         128         929       0.563       0.949        0.92       0.656
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     74/299     4.51G   0.03819   0.04643  0.006946   0.09156       179       640: 100%|██████████| 8/8 [00:02<00:00,  3.66it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.99it/s]
#                  all         128         929        0.56       0.948       0.922       0.656
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     75/299     4.51G   0.03963   0.04266  0.007328   0.08962       186       640: 100%|██████████| 8/8 [00:02<00:00,  3.54it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.64it/s]
#                  all         128         929       0.565       0.946       0.915       0.633
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     76/299     4.51G   0.03894   0.04731  0.006743   0.09299       193       640: 100%|██████████| 8/8 [00:02<00:00,  3.48it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.48it/s]
#                  all         128         929       0.599       0.941       0.921       0.668
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     77/299     4.51G   0.03804   0.04738  0.007294   0.09271       249       640: 100%|██████████| 8/8 [00:02<00:00,  3.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.62it/s]
#                  all         128         929       0.607       0.943       0.924       0.654
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     78/299     4.51G   0.03899   0.04187  0.007389   0.08826       235       640: 100%|██████████| 8/8 [00:02<00:00,  3.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.71it/s]
#                  all         128         929       0.579       0.938       0.911       0.642
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     79/299     4.51G   0.03777   0.04645  0.007631   0.09185       269       640: 100%|██████████| 8/8 [00:02<00:00,  3.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.74it/s]
#                  all         128         929       0.575       0.948       0.918       0.644
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     80/299     4.51G   0.03959   0.04315  0.006332   0.08908       176       640: 100%|██████████| 8/8 [00:02<00:00,  3.67it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.76it/s]
#                  all         128         929        0.58       0.951       0.924       0.646
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     81/299     4.51G   0.03983    0.0435  0.006844   0.09017       227       640: 100%|██████████| 8/8 [00:02<00:00,  3.52it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.66it/s]
#                  all         128         929       0.569       0.951       0.931       0.608
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     82/299     4.51G   0.03858   0.04306   0.00667   0.08831       180       640: 100%|██████████| 8/8 [00:02<00:00,  3.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.75it/s]
#                  all         128         929       0.564       0.948       0.931       0.672
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     83/299     4.51G   0.04005   0.04437  0.006941   0.09137       311       640: 100%|██████████| 8/8 [00:02<00:00,  3.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.62it/s]
#                  all         128         929       0.557       0.953       0.921       0.644
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     84/299     4.51G   0.03979   0.04483  0.007325   0.09194       214       640: 100%|██████████| 8/8 [00:02<00:00,  3.61it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.54it/s]
#                  all         128         929       0.565       0.944       0.925       0.618
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     85/299     4.51G   0.04063   0.04705  0.007539   0.09522       180       640: 100%|██████████| 8/8 [00:02<00:00,  3.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.13it/s]
#                  all         128         929       0.554       0.953        0.92       0.627
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     86/299     4.51G   0.03804   0.04527  0.007424   0.09073       186       640: 100%|██████████| 8/8 [00:02<00:00,  3.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.64it/s]
#                  all         128         929       0.563       0.947       0.921        0.62
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     87/299     4.51G   0.03884   0.03973  0.006802   0.08538       152       640: 100%|██████████| 8/8 [00:02<00:00,  3.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.11it/s]
#                  all         128         929       0.578       0.951        0.92       0.634
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     88/299     4.51G    0.0379   0.04128  0.006187   0.08537       146       640: 100%|██████████| 8/8 [00:02<00:00,  3.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.96it/s]
#                  all         128         929       0.581       0.951        0.92       0.642
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     89/299     4.51G    0.0405   0.04386   0.00792   0.09229       199       640: 100%|██████████| 8/8 [00:02<00:00,  3.76it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.98it/s]
#                  all         128         929       0.572       0.949       0.921       0.645
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     90/299     4.51G   0.03879   0.03669  0.007655   0.08313       206       640: 100%|██████████| 8/8 [00:02<00:00,  3.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.04it/s]
#                  all         128         929       0.607       0.951       0.921       0.641
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     91/299     4.51G   0.03761   0.04201   0.00734   0.08695       194       640: 100%|██████████| 8/8 [00:02<00:00,  3.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.66it/s]
#                  all         128         929       0.585       0.957       0.933       0.622
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     92/299     4.51G   0.04233   0.04811  0.006805   0.09725       190       640: 100%|██████████| 8/8 [00:02<00:00,  3.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.68it/s]
#                  all         128         929       0.578       0.959       0.926       0.594
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     93/299     4.51G   0.04197   0.04518  0.006345    0.0935       166       640: 100%|██████████| 8/8 [00:02<00:00,  3.67it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.04it/s]
#                  all         128         929        0.57       0.951       0.922       0.609
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     94/299     4.51G   0.03848   0.04266  0.006792   0.08792       131       640: 100%|██████████| 8/8 [00:02<00:00,  3.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.99it/s]
#                  all         128         929       0.582       0.952       0.934       0.647
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#     95/299     4.51G    0.0374    0.0439  0.006997    0.0883       160       640: 100%|██████████| 8/8 [00:02<00:00,  3.76it/s]
# ...
#                  all         128         929       0.661       0.975       0.968        0.79
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    270/299     4.51G   0.02794   0.03609  0.004436   0.06846       155       640: 100%|██████████| 8/8 [00:02<00:00,  3.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.88it/s]
#                  all         128         929       0.664       0.976       0.968       0.792
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    271/299     4.51G   0.02863    0.0319  0.004807   0.06534       104       640: 100%|██████████| 8/8 [00:02<00:00,  3.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.86it/s]
#                  all         128         929       0.662       0.976       0.967       0.785
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    272/299     4.51G   0.02992   0.03326  0.004418    0.0676       228       640: 100%|██████████| 8/8 [00:02<00:00,  3.56it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.48it/s]
#                  all         128         929       0.658       0.977       0.967       0.779
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    273/299     4.51G   0.03064   0.03568  0.004334   0.07065       309       640: 100%|██████████| 8/8 [00:02<00:00,  3.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.91it/s]
#                  all         128         929       0.663       0.976       0.968        0.79
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    274/299     4.51G   0.03003    0.0314  0.004449   0.06588       189       640: 100%|██████████| 8/8 [00:02<00:00,  3.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.75it/s]
#                  all         128         929       0.663       0.975       0.967       0.777
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    275/299     4.51G   0.02958   0.03205  0.004162   0.06578       218       640: 100%|██████████| 8/8 [00:02<00:00,  3.61it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.21it/s]
#                  all         128         929       0.671       0.977       0.968       0.786
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    276/299     4.51G   0.02927   0.03221  0.004344   0.06582       249       640: 100%|██████████| 8/8 [00:02<00:00,  3.73it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.86it/s]
#                  all         128         929       0.676       0.976       0.967       0.783
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    277/299     4.51G   0.02847   0.03263  0.004072   0.06517       219       640: 100%|██████████| 8/8 [00:02<00:00,  3.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.98it/s]
#                  all         128         929       0.675       0.973       0.967       0.786
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    278/299     4.51G   0.02775   0.03293  0.004226   0.06491       237       640: 100%|██████████| 8/8 [00:02<00:00,  3.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.98it/s]
#                  all         128         929        0.68       0.975       0.967       0.782
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    279/299     4.51G   0.02937   0.03453  0.004857   0.06876       198       640: 100%|██████████| 8/8 [00:02<00:00,  3.58it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.33it/s]
#                  all         128         929       0.673       0.975       0.966       0.786
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    280/299     4.51G   0.02776   0.03158  0.004254   0.06359       110       640: 100%|██████████| 8/8 [00:02<00:00,  3.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.01it/s]
#                  all         128         929       0.665       0.977       0.966       0.785
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    281/299     4.51G   0.03084   0.03428  0.004973   0.07009       150       640: 100%|██████████| 8/8 [00:02<00:00,  3.70it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.93it/s]
#                  all         128         929       0.667       0.976       0.967       0.794
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    282/299     4.51G   0.02796   0.03259  0.004111   0.06466       175       640: 100%|██████████| 8/8 [00:02<00:00,  3.62it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.07it/s]
#                  all         128         929       0.667       0.977       0.967       0.793
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    283/299     4.51G   0.02705   0.02839  0.004076   0.05952       163       640: 100%|██████████| 8/8 [00:02<00:00,  3.77it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.82it/s]
#                  all         128         929       0.665       0.978       0.967         0.8
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    284/299     4.51G   0.02766   0.03697  0.004497   0.06912       291       640: 100%|██████████| 8/8 [00:02<00:00,  3.69it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.86it/s]
#                  all         128         929       0.667       0.978       0.967       0.788
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    285/299     4.51G   0.02882   0.03234  0.004528   0.06569       158       640: 100%|██████████| 8/8 [00:02<00:00,  3.67it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.13it/s]
#                  all         128         929       0.666       0.979       0.968       0.796
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    286/299     4.51G   0.02655     0.031  0.004058   0.06161       184       640: 100%|██████████| 8/8 [00:02<00:00,  3.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.94it/s]
#                  all         128         929       0.662       0.979       0.968       0.792
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    287/299     4.51G   0.02787   0.03168  0.004392   0.06395       191       640: 100%|██████████| 8/8 [00:02<00:00,  3.60it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.84it/s]
#                  all         128         929       0.664       0.975       0.967       0.801
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    288/299     4.51G   0.02869   0.03579  0.004231   0.06872       223       640: 100%|██████████| 8/8 [00:02<00:00,  3.68it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.63it/s]
#                  all         128         929       0.666        0.98        0.97       0.796
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    289/299     4.51G   0.02856   0.03177  0.004318   0.06465       158       640: 100%|██████████| 8/8 [00:02<00:00,  3.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.56it/s]
#                  all         128         929       0.666       0.976       0.968       0.797
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    290/299     4.51G   0.02919    0.0334  0.004595   0.06718       256       640: 100%|██████████| 8/8 [00:02<00:00,  3.72it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.10it/s]
#                  all         128         929       0.673       0.977       0.969       0.796
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    291/299     4.51G   0.02919   0.03293  0.004949   0.06706       238       640: 100%|██████████| 8/8 [00:02<00:00,  3.66it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.83it/s]
#                  all         128         929       0.672       0.974       0.968       0.794
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    292/299     4.51G   0.02757   0.03319  0.004447   0.06521       206       640: 100%|██████████| 8/8 [00:02<00:00,  3.75it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.81it/s]
#                  all         128         929       0.677       0.976        0.97       0.797
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    293/299     4.51G   0.02821    0.0358  0.004197   0.06821       199       640: 100%|██████████| 8/8 [00:02<00:00,  3.53it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.68it/s]
#                  all         128         929       0.684       0.976        0.97         0.8
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    294/299     4.51G   0.02796   0.03393  0.004671   0.06656       188       640: 100%|██████████| 8/8 [00:02<00:00,  3.73it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.43it/s]
#                  all         128         929       0.686       0.977       0.969       0.795
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    295/299     4.51G   0.02932   0.03204  0.004289   0.06565       253       640: 100%|██████████| 8/8 [00:02<00:00,  3.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.04it/s]
#                  all         128         929       0.682       0.977       0.969       0.794
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    296/299     4.51G    0.0269   0.03136  0.004083   0.06234       180       640: 100%|██████████| 8/8 [00:02<00:00,  3.65it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  5.57it/s]
#                  all         128         929       0.676       0.974       0.968       0.793
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    297/299     4.51G   0.02915   0.03452  0.004233    0.0679       235       640: 100%|██████████| 8/8 [00:02<00:00,  3.64it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.10it/s]
#                  all         128         929       0.672       0.974       0.967       0.797
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    298/299     4.51G   0.02706   0.03422  0.004324    0.0656       194       640: 100%|██████████| 8/8 [00:02<00:00,  3.63it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:01<00:00,  6.06it/s]
#                  all         128         929       0.671       0.977       0.967         0.8
#
#      Epoch   gpu_mem       box       obj       cls     total   targets  img_size
#    299/299     4.51G   0.02792   0.03442  0.003849   0.06619       274       640: 100%|██████████| 8/8 [00:02<00:00,  3.71it/s]
#                Class      Images     Targets           P           R      mAP@.5  mAP@.5:.95: 100%|██████████| 8/8 [00:03<00:00,  2.03it/s]
#                  all         128         929       0.673       0.974       0.967       0.798
# Images sizes do not match. This will causes images to be display incorrectly in the UI.
# Optimizer stripped from runs/train/exp2/weights/last.pt, 15.2MB
# Images sizes do not match. This will causes images to be display incorrectly in the UI.
# 300 epochs completed in 0.314 hours.
#
#
# wandb: Waiting for W&B process to finish, PID 430
# wandb: Program ended successfully.
# wandb:
# wandb: Find user logs for this run at: /content/yolov5/wandb/run-20201224_014226-29or7gxf/logs/debug.log
# wandb: Find internal logs for this run at: /content/yolov5/wandb/run-20201224_014226-29or7gxf/logs/debug-internal.log
# wandb: Run summary:
# wandb:                  _step 3904
# wandb:               _runtime 1136
# wandb:             _timestamp 1608775282
# wandb:         train/box_loss 0.02792
# wandb:         train/obj_loss 0.03442
# wandb:         train/cls_loss 0.00385
# wandb:      metrics/precision 0.67345
# wandb:         metrics/recall 0.97435
# wandb:        metrics/mAP_0.5 0.9667
# wandb:   metrics/mAP_0.5:0.95 0.79767
# wandb:           val/box_loss 0.02129
# wandb:           val/obj_loss 0.01778
# wandb:           val/cls_loss 0.00247
# wandb:                  x/lr0 0.002
# wandb:                  x/lr1 0.002
# wandb:                  x/lr2 0.002
# wandb: Run history:
# wandb:                  _step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:               _runtime ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:             _timestamp ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:         train/box_loss ▇█▆▆▅▆▆▅▅▆▆▆▅▅▆▆▆█▆▆▅▅▅▃▄▃▄▃▃▃▁▃▂▁▂▁▂▁▂▁
# wandb:         train/obj_loss ██▆▇▆▆▅▄▄▄▄▄▄▄▅▃▄▅▄▄▄▃▄▃▃▂▂▂▃▂▂▃▂▂▂▂▂▁▂▂
# wandb:         train/cls_loss ██▆▅▅▄▄▃▃▃▃▃▃▃▃▃▃▃▂▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▂▁
# wandb:      metrics/precision ▁▁▂▃▄▄▄▅▃▅▅▅▆▆▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇██▇███████
# wandb:         metrics/recall ▁▂▃▄▅▅▆▇▇▆▇▇▇▇▇▇▇▇▇▇████████████████████
# wandb:        metrics/mAP_0.5 ▁▂▃▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█▇█████████████████
# wandb:   metrics/mAP_0.5:0.95 ▁▁▂▃▄▄▅▅▃▄▄▅▄▄▄▅▅▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇██████
# wandb:           val/box_loss ██▇▇▇▇▆▅█▇▆▆▆▆▇▆▆▆▇▆▅▅▅▃▄▃▄▃▃▂▂▂▂▂▂▁▁▁▁▁
# wandb:           val/obj_loss ██▇▆▅▅▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁
# wandb:           val/cls_loss █▇▅▄▃▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁
# wandb:                  x/lr0 ▁▁▂▃▃▄▄▅▆▆▆▇▇▇████▇▇▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▃▃▃
# wandb:                  x/lr1 ▁▁▂▃▃▄▄▅▆▆▆▇▇▇████▇▇▇▇▆▆▆▅▅▅▄▄▄▄▃▃▃▃▃▃▃▃
# wandb:                  x/lr2 ██▇▇▇▆▆▅▅▄▄▄▃▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Synced 5 W&B file(s), 46 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced exp2: https://wandb.ai/wmh02240/YOLOv5/runs/29or7gxf

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://www.wandb.com/) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <img src="https://user-images.githubusercontent.com/26833433/98184457-bd3da580-1f0a-11eb-8461-95d908a71893.jpg" width="800">

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and test jpgs to see mosaics, labels, predictions and augmentation effects. Note a **Mosaic Dataloader** is used for training (shown below), a new concept developed by Ultralytics and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='runs/train/exp/train_batch0.jpg', width=800)  # train batch 0 mosaics and labels
Image(filename='runs/train/exp/test_batch0_labels.jpg', width=800)  # test batch 0 labels
Image(filename='runs/train/exp/test_batch0_pred.jpg', width=800)  # test batch 0 predictions

# %% [markdown]
# > <img src="https://user-images.githubusercontent.com/26833433/83667642-90fcb200-a583-11ea-8fa3-338bbf7da194.jpeg" width="750">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667626-8c37fe00-a583-11ea-997b-0923fe59b29b.jpeg" width="750">
# `test_batch0_labels.jpg` shows test batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/83667635-90641b80-a583-11ea-8075-606316cebb9c.jpeg" width="750">
# `test_batch0_pred.jpg` shows test batch 0 _predictions_

# %% [markdown]
# Training losses and performance metrics are also logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and a custom `results.txt` logfile which is plotted as `results.png` (below) after training completes. Here we show YOLOv5s trained on COCO128 to 300 epochs, starting from scratch (blue), and from pretrained `--weights yolov5s.pt` (orange).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 新段落

# %%
from utils.plots import plot_results 
plot_results(save_dir='runs/train/exp')  # plot all results*.txt as results.png
Image(filename='runs/train/exp/results.png', width=800)

# %% [markdown]
# <img src="https://user-images.githubusercontent.com/26833433/97808309-8182b180-1c66-11eb-8461-bffe1a79511d.png" width="800">

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab Notebook** with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
# - **Kaggle Notebook** with free GPU: [https://www.kaggle.com/ultralytics/yolov5](https://www.kaggle.com/ultralytics/yolov5)
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Docker Image** https://hub.docker.com/r/ultralytics/yolov5. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) ![Docker Pulls](https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker)

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Re-clone repo
# %cd ..
# %rm -rf yolov5 && git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# %%
# Test all
# %%shell
for x in s m l x; do
  python test.py --weights yolov5$x.pt --data coco.yaml --img 640
done

# %%
# Unit tests
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories

rm -rf runs  # remove runs/
for m in yolov5s; do  # models
  python train.py --weights $m.pt --epochs 3 --img 320 --device 0  # train pretrained
  python train.py --weights '' --cfg $m.yaml --epochs 3 --img 320 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
    python test.py --weights $m.pt --device $d # test official
    python test.py --weights runs/train/exp/weights/best.pt --device $d # test custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # inspect
  python models/export.py --weights $m.pt --img 640 --batch 1  # export
done

# %%
# Profile
from utils.torch_utils import profile 

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
profile(x=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data voc.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}
